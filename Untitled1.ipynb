# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

def encode_categorical(df):
    label_encoder = LabelEncoder()
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = label_encoder.fit_transform(df[column])
    return df

df1 = pd.read_csv('train.csv')
df1 = encode_categorical(df1)

df2 = pd.read_csv('test.csv')
df2 = encode_categorical(df2)
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      2
# 1        2          20         3         80.0     9600       1      2
# 2        3          60         3         68.0    11250       1      2
# 3        4          70         3         60.0     9550       1      2
# 4        5          60         3         84.0    14260       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      2
# 1456  1457          20         3         85.0    13175       1      2
# 1457  1458          70         3         66.0     9042       1      2
# 1458  1459          20         3         68.0     9717       1      2
# 1459  1460          20         3         75.0     9937       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0            3            3          0  ...         0       3      4
# 1            3            3          0  ...         0       3      4
# 2            0            3          0  ...         0       3      4
# 3            0            3          0  ...         0       3      4
# 4            0            3          0  ...         0       3      4
# ...        ...          ...        ...  ...       ...     ...    ...
# 1455         3            3          0  ...         0       3      4
# 1456         3            3          0  ...         0       3      2
# 1457         3            3          0  ...         0       3      0
# 1458         3            3          0  ...         0       3      4
# 1459         3            3          0  ...         0       3      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0               4        0       2    2008         8              4     208500
# 1               4        0       5    2007         8              4     181500
# 2               4        0       9    2008         8              4     223500
# 3               4        0       2    2006         8              0     140000
# 4               4        0      12    2008         8              4     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455            4        0       8    2007         8              4     175000
# 1456            4        0       2    2010         8              4     210000
# 1457            2     2500       5    2010         8              4     266500
# 1458            4        0       4    2010         8              4     142125
# 1459            4        0       6    2008         8              4     147500
#
# [1460 rows x 81 columns]

# %%
import torch.utils.data as Data
import torch

x_train = df1.iloc[:,:-1]
y_train = df1.iloc[:,-1:]
x_test = df2.iloc[:,:-1]
y_test = df2.iloc[:,-1:]

batch_sizes = 16

x_train_tensor = torch.tensor(x_train.values)
y_train_tensor = torch.tensor(y_train.values)
x_test_tensor = torch.tensor(x_test.values)
y_test_tensor = torch.tensor(y_test.values)

train_dataset = Data.TensorDataset(x_train_tensor, y_train_tensor)
test_dataset = Data.TensorDataset(x_test_tensor, y_test_tensor)

train_dataloader = Data.DataLoader(train_dataset,batch_sizes,shuffle=True)
test_dataloader = Data.DataLoader(test_dataset,batch_sizes,shuffle=True)

# %%
import torch.nn as nn
class LinearNet(nn.Module):
    def __init__(self,in_features,out_features):
        super().__init__()
        self.linear = nn.Linear(in_features,out_features)
        self.activation = nn.Sigmoid()
    
    def forward(self,x):
        y = self.linear(x)
        y = self.activation(y)
        return y

# %%
import torch.optim as optim
loss = nn.MSELoss()
model = LinearNet(81,1)
optimizer = optim.Adam(model.parameters(),lr=1e-3)

# %%
def train_model(model,dataloader):
    model.train()
    
    total_loss = 0
    for idx,(x,y) in enumerate(dataloader):
        y_pred = model(x)
        cur_loss = loss(y_pred,y)
        optimizer.zero_grad()
        cur_loss.backward()
        optimizer.step()
        
        total_loss += cur_loss.item()
    print(f"train loss:{total_loss/len(train_dataset)}")

# %%
Epoch = 10
for i in range(Epoch):
    train_model(model,train_dataloader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-70-e2347302927f> in <module>
#       1 Epoch = 10
#       2 for i in range(Epoch):
# ----> 3     train_model(model,train_dataloader)
#
# <ipython-input-68-a77192b46611> in train_model(model, dataloader)
#       4     total_loss = 0
#       5     for idx,(x,y) in enumerate(dataloader):
# ----> 6         y_pred = model(x)
#       7         cur_loss = loss(y_pred.to(y.dtype), y)
#       8
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-55-9a6eceb1ae49> in forward(self, x)
#       7
#       8     def forward(self,x):
# ----> 9         y = self.linear(x)
#      10         y = self.activation(y)
#      11         return y
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# D:\anaconda\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 must have the same dtype, but got Double and Float
